# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file
file_path = 'results.json'  # Replace with your file path
data = pd.read_json(file_path)

# Initialize empty arrays for times
times = []
depth = [result["parameters"]["depth"] for result in data["results"]]

# Extract the times from the JSON structure
for result in data["results"]:
   times.append(result["times"])

# Create a 2x10 NumPy array
times_array = np.array(times).T  # Transpose the array

df = pd.DataFrame(times_array, columns=depth)

# Create the box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df)

# # Add the line plot
# means = 
# plt.plot(range(1, len(parameter_depths) + 1), means, marker='o', color='b')

# Label the axes
plt.xlabel('queue-depth')
plt.ylabel('time (ms)')

# Set x-axis labels to the unique parameter_depth values
plt.xticks(range(1, len(parameter_depths) + 1), parameter_depths)

# Show the plot
plt.title('Box plot and Line plot of mean time vs queue depth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parameter_depth'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import numpy as np
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4),
                   columns=['Col1', 'Col2', 'Col3', 'Col4'])
print(df)
# Out:
#        Col1      Col2      Col3      Col4
# 0  0.471435 -1.190976  1.432707 -0.312652
# 1 -0.720589  0.887163  0.859588 -0.636524
# 2  0.015696 -2.242685  1.150036  0.991946
# 3  0.953324 -2.021255 -0.334077  0.002118
# 4  0.405453  0.289092  1.321158 -1.546906
# 5 -0.202646 -0.655969  0.193421  0.553439
# 6  1.318152 -0.469305  0.675554 -1.817027
# 7 -0.183109  1.058969 -0.397840  0.337438
# 8  1.047579  1.045938  0.863717 -0.122092
# 9  0.124713 -0.322795  0.841675  2.390961
